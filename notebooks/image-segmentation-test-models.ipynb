# %%
import os
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import CustomObjectScope
import numpy as np
from tensorflow.keras.utils import Sequence

# %%
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = tf.keras.layers.Flatten()(y_true)
    y_pred_f = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
def mask_to_3d(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
def parse_image(img_path, image_size):
    image_rgb = cv2.imread(img_path, 1)
    h, w, _ = image_rgb.shape
    if (h == image_size) and (w == image_size):
        pass
    else:
        image_rgb = cv2.resize(image_rgb, (image_size, image_size))
    image_rgb = image_rgb/255.0
    return image_rgb

def parse_mask(mask_path, image_size):
    mask = cv2.imread(mask_path, -1)
    h, w = mask.shape
    if (h == image_size) and (w == image_size):
        pass
    else:
        mask = cv2.resize(mask, (image_size, image_size))
    mask = np.expand_dims(mask, -1)
    mask = mask/255.0

    return mask

# %%
class DataGen(Sequence):
    def __init__(self, image_size, images_path, masks_path, batch_size=8):
        self.image_size = image_size
        self.images_path = images_path
        self.masks_path = masks_path
        self.batch_size = batch_size
        self.on_epoch_end()

    def __getitem__(self, index):
        if(index+1)*self.batch_size > len(self.images_path):
            self.batch_size = len(self.images_path) - index*self.batch_size

        images_path = self.images_path[index*self.batch_size : (index+1)*self.batch_size]
        masks_path = self.masks_path[index*self.batch_size : (index+1)*self.batch_size]

        images_batch = []
        masks_batch = []

        for i in range(len(images_path)):
            ## Read image and mask
            image = parse_image(images_path[i], self.image_size)
            mask = parse_mask(masks_path[i], self.image_size)

            images_batch.append(image)
            masks_batch.append(mask)

        return np.array(images_batch), np.array(masks_batch)

    def on_epoch_end(self):
        pass

    def __len__(self):
        return int(np.ceil(len(self.images_path)/float(self.batch_size)))

# %%
def test_model(model_path, save_path):
    model_path = model_path
    save_path = save_path
    test_path = "../input/kvasit-seg-train-test-valid/data/content/new_data/Kvasir-SEG/test"
    
    image_size = 256
    batch_size = 1
    
    test_image_paths = glob(os.path.join(test_path, "images", "*"))
    test_mask_paths = glob(os.path.join(test_path, "masks", "*"))
    test_image_paths.sort()
    test_mask_paths.sort()
    
    ## Create result folder
    try:
        os.mkdir(save_path)
    except:
        pass
    
    ## Model
    with CustomObjectScope({'dice_loss': dice_loss, 'dice_coef': dice_coef}):
        model = load_model(model_path)

    ## Test
    print("Test Result: ")
    test_steps = len(test_image_paths)//batch_size
    test_gen = DataGen(image_size, test_image_paths, test_mask_paths, batch_size=batch_size)
    model.evaluate_generator(test_gen, steps=test_steps, verbose=1)

    ## Generating the result
    for i, path in tqdm(enumerate(test_image_paths), total=len(test_image_paths)):
        image = parse_image(test_image_paths[i], image_size)
        mask = parse_mask(test_mask_paths[i], image_size)

        predict_mask = model.predict(np.expand_dims(image, axis=0))[0]
        predict_mask = (predict_mask > 0.5) * 255.0

        sep_line = np.ones((image_size, 10, 3)) * 255

        mask = mask_to_3d(mask)
        predict_mask = mask_to_3d(predict_mask)

        all_images = [image * 255, sep_line, mask * 255, sep_line, predict_mask]
        cv2.imwrite(f"{save_path}/{i}.png", np.concatenate(all_images, axis=1))

    print("Test image generation complete")

# %%
model_path = "../input/kvasit-seg-train-test-valid/model_comparison_files/model_comparision_files/resunetplusplus.h5"
save_path = "./resunetplusplus"
test_model(model_path, save_path)
# Out:
# Test Result:
# 100/100 [==============================] - 4s 26ms/step - loss: 0.2774 - recall: 0.4968 - precision: 0.9312 - dice_coef: 0.7226 - mean_io_u: 0.6510
# 100%|██████████| 100/100 [00:07<00:00, 13.05it/s]
# Test image generation complete

# %%
model_path = "../input/kvasit-seg-train-test-valid/model_comparison_files/model_comparision_files/unet.h5"
save_path = "./unet"
test_model(model_path, save_path)
# Out:
# Test Result:
# 100/100 [==============================] - 2s 12ms/step - loss: 0.3258 - recall_1: 0.7646 - precision_1: 0.7203 - dice_coef: 0.6742 - mean_io_u_1: 0.4246
# 100%|██████████| 100/100 [00:06<00:00, 14.83it/s]
# Test image generation complete

# %%
model_path = "../input/kvasit-seg-train-test-valid/model_comparison_files/model_comparision_files/resunet.h5"
save_path = "./resunet"
test_model(model_path, save_path)
# Out:
# Test Result:
# 100/100 [==============================] - 3s 15ms/step - loss: 0.3450 - recall: 0.6446 - precision: 0.8134 - dice_coef: 0.6550 - mean_io_u: 0.4246
# 100%|██████████| 100/100 [00:07<00:00, 13.98it/s]
# Test image generation complete

# %%
# !zip -r ./resunetplusplus.zip ./resunetplusplus
# Out:
#   adding: resunetplusplus/ (stored 0%)
#   adding: resunetplusplus/23.png (deflated 4%)
#   adding: resunetplusplus/13.png (deflated 2%)
#   adding: resunetplusplus/68.png (deflated 3%)
#   adding: resunetplusplus/31.png (deflated 3%)
#   adding: resunetplusplus/5.png (deflated 3%)
#   adding: resunetplusplus/62.png (deflated 2%)
#   adding: resunetplusplus/59.png (deflated 3%)
#   adding: resunetplusplus/19.png (deflated 3%)
#   adding: resunetplusplus/60.png (deflated 4%)
#   adding: resunetplusplus/93.png (deflated 3%)
#   adding: resunetplusplus/48.png (deflated 3%)
#   adding: resunetplusplus/37.png (deflated 3%)
#   adding: resunetplusplus/35.png (deflated 2%)
#   adding: resunetplusplus/73.png (deflated 3%)
#   adding: resunetplusplus/11.png (deflated 3%)
#   adding: resunetplusplus/77.png (deflated 2%)
#   adding: resunetplusplus/45.png (deflated 3%)
#   adding: resunetplusplus/55.png (deflated 2%)
#   adding: resunetplusplus/83.png (deflated 4%)
#   adding: resunetplusplus/33.png (deflated 3%)
#   adding: resunetplusplus/34.png (deflated 3%)
#   adding: resunetplusplus/86.png (deflated 4%)
#   adding: resunetplusplus/80.png (deflated 3%)
#   adding: resunetplusplus/50.png (deflated 4%)
#   adding: resunetplusplus/30.png (deflated 4%)
#   adding: resunetplusplus/94.png (deflated 4%)
#   adding: resunetplusplus/95.png (deflated 3%)
#   adding: resunetplusplus/21.png (deflated 3%)
#   adding: resunetplusplus/89.png (deflated 5%)
#   adding: resunetplusplus/28.png (deflated 3%)
#   adding: resunetplusplus/41.png (deflated 4%)
#   adding: resunetplusplus/51.png (deflated 4%)
#   adding: resunetplusplus/84.png (deflated 4%)
#   adding: resunetplusplus/71.png (deflated 3%)
#   adding: resunetplusplus/10.png (deflated 3%)
#   adding: resunetplusplus/75.png (deflated 4%)
#   adding: resunetplusplus/85.png (deflated 3%)
#   adding: resunetplusplus/6.png (deflated 3%)
#   adding: resunetplusplus/39.png (deflated 3%)
#   adding: resunetplusplus/27.png (deflated 3%)
#   adding: resunetplusplus/46.png (deflated 5%)
#   adding: resunetplusplus/12.png (deflated 3%)
#   adding: resunetplusplus/38.png (deflated 3%)
#   adding: resunetplusplus/90.png (deflated 3%)
#   adding: resunetplusplus/2.png (deflated 5%)
#   adding: resunetplusplus/74.png (deflated 2%)
#   adding: resunetplusplus/56.png (deflated 3%)
#   adding: resunetplusplus/64.png (deflated 3%)
#   adding: resunetplusplus/47.png (deflated 3%)
#   adding: resunetplusplus/36.png (deflated 3%)
#   adding: resunetplusplus/26.png (deflated 3%)
#   adding: resunetplusplus/99.png (deflated 3%)
#   adding: resunetplusplus/20.png (deflated 4%)
#   adding: resunetplusplus/42.png (deflated 2%)
#   adding: resunetplusplus/91.png (deflated 4%)
#   adding: resunetplusplus/66.png (deflated 3%)
#   adding: resunetplusplus/24.png (deflated 3%)
#   adding: resunetplusplus/9.png (deflated 3%)
#   adding: resunetplusplus/32.png (deflated 2%)
#   adding: resunetplusplus/0.png (deflated 3%)
#   adding: resunetplusplus/65.png (deflated 3%)
#   adding: resunetplusplus/44.png (deflated 3%)
#   adding: resunetplusplus/72.png (deflated 3%)
#   adding: resunetplusplus/98.png (deflated 4%)
#   adding: resunetplusplus/88.png (deflated 3%)
#   adding: resunetplusplus/96.png (deflated 3%)
#   adding: resunetplusplus/18.png (deflated 4%)
#   adding: resunetplusplus/87.png (deflated 3%)
#   adding: resunetplusplus/22.png (deflated 2%)
#   adding: resunetplusplus/78.png (deflated 2%)
#   adding: resunetplusplus/92.png (deflated 4%)
#   adding: resunetplusplus/58.png (deflated 3%)
#   adding: resunetplusplus/52.png (deflated 4%)
#   adding: resunetplusplus/16.png (deflated 3%)
#   adding: resunetplusplus/61.png (deflated 3%)
#   adding: resunetplusplus/40.png (deflated 2%)
#   adding: resunetplusplus/8.png (deflated 3%)
#   adding: resunetplusplus/70.png (deflated 3%)
#   adding: resunetplusplus/3.png (deflated 2%)
#   adding: resunetplusplus/14.png (deflated 3%)
#   adding: resunetplusplus/57.png (deflated 3%)
#   adding: resunetplusplus/54.png (deflated 3%)
#   adding: resunetplusplus/53.png (deflated 2%)
#   adding: resunetplusplus/1.png (deflated 3%)
#   adding: resunetplusplus/15.png (deflated 3%)
#   adding: resunetplusplus/17.png (deflated 2%)
#   adding: resunetplusplus/76.png (deflated 4%)
#   adding: resunetplusplus/7.png (deflated 3%)
#   adding: resunetplusplus/69.png (deflated 3%)
#   adding: resunetplusplus/67.png (deflated 3%)
#   adding: resunetplusplus/25.png (deflated 3%)
#   adding: resunetplusplus/82.png (deflated 3%)
#   adding: resunetplusplus/79.png (deflated 3%)
#   adding: resunetplusplus/4.png (deflated 2%)
#   adding: resunetplusplus/63.png (deflated 3%)
#   adding: resunetplusplus/81.png (deflated 4%)
#   adding: resunetplusplus/49.png (deflated 3%)
#   adding: resunetplusplus/97.png (deflated 3%)
#   adding: resunetplusplus/43.png (deflated 3%)
#   adding: resunetplusplus/29.png (deflated 3%)

# %%
# !zip -r ./resunet.zip ./resunet
# Out:
#   adding: resunet/ (stored 0%)
#   adding: resunet/23.png (deflated 4%)
#   adding: resunet/13.png (deflated 2%)
#   adding: resunet/68.png (deflated 2%)
#   adding: resunet/31.png (deflated 3%)
#   adding: resunet/5.png (deflated 3%)
#   adding: resunet/62.png (deflated 2%)
#   adding: resunet/59.png (deflated 3%)
#   adding: resunet/19.png (deflated 2%)
#   adding: resunet/60.png (deflated 4%)
#   adding: resunet/93.png (deflated 3%)
#   adding: resunet/48.png (deflated 3%)
#   adding: resunet/37.png (deflated 3%)
#   adding: resunet/35.png (deflated 2%)
#   adding: resunet/73.png (deflated 3%)
#   adding: resunet/11.png (deflated 3%)
#   adding: resunet/77.png (deflated 2%)
#   adding: resunet/45.png (deflated 3%)
#   adding: resunet/55.png (deflated 2%)
#   adding: resunet/83.png (deflated 4%)
#   adding: resunet/33.png (deflated 3%)
#   adding: resunet/34.png (deflated 3%)
#   adding: resunet/86.png (deflated 4%)
#   adding: resunet/80.png (deflated 2%)
#   adding: resunet/50.png (deflated 4%)
#   adding: resunet/30.png (deflated 4%)
#   adding: resunet/94.png (deflated 4%)
#   adding: resunet/95.png (deflated 2%)
#   adding: resunet/21.png (deflated 3%)
#   adding: resunet/89.png (deflated 5%)
#   adding: resunet/28.png (deflated 3%)
#   adding: resunet/41.png (deflated 4%)
#   adding: resunet/51.png (deflated 4%)
#   adding: resunet/84.png (deflated 4%)
#   adding: resunet/71.png (deflated 3%)
#   adding: resunet/10.png (deflated 3%)
#   adding: resunet/75.png (deflated 4%)
#   adding: resunet/85.png (deflated 3%)
#   adding: resunet/6.png (deflated 3%)
#   adding: resunet/39.png (deflated 3%)
#   adding: resunet/27.png (deflated 3%)
#   adding: resunet/46.png (deflated 5%)
#   adding: resunet/12.png (deflated 3%)
#   adding: resunet/38.png (deflated 3%)
#   adding: resunet/90.png (deflated 3%)
#   adding: resunet/2.png (deflated 5%)
#   adding: resunet/74.png (deflated 2%)
#   adding: resunet/56.png (deflated 3%)
#   adding: resunet/64.png (deflated 3%)
#   adding: resunet/47.png (deflated 3%)
#   adding: resunet/36.png (deflated 3%)
#   adding: resunet/26.png (deflated 3%)
#   adding: resunet/99.png (deflated 3%)
#   adding: resunet/20.png (deflated 4%)
#   adding: resunet/42.png (deflated 2%)
#   adding: resunet/91.png (deflated 4%)
#   adding: resunet/66.png (deflated 3%)
#   adding: resunet/24.png (deflated 3%)
#   adding: resunet/9.png (deflated 3%)
#   adding: resunet/32.png (deflated 2%)
#   adding: resunet/0.png (deflated 3%)
#   adding: resunet/65.png (deflated 3%)
#   adding: resunet/44.png (deflated 3%)
#   adding: resunet/72.png (deflated 3%)
#   adding: resunet/98.png (deflated 3%)
#   adding: resunet/88.png (deflated 3%)
#   adding: resunet/96.png (deflated 4%)
#   adding: resunet/18.png (deflated 4%)
#   adding: resunet/87.png (deflated 3%)
#   adding: resunet/22.png (deflated 2%)
#   adding: resunet/78.png (deflated 2%)
#   adding: resunet/92.png (deflated 4%)
#   adding: resunet/58.png (deflated 3%)
#   adding: resunet/52.png (deflated 4%)
#   adding: resunet/16.png (deflated 3%)
#   adding: resunet/61.png (deflated 3%)
#   adding: resunet/40.png (deflated 3%)
#   adding: resunet/8.png (deflated 3%)
#   adding: resunet/70.png (deflated 2%)
#   adding: resunet/3.png (deflated 2%)
#   adding: resunet/14.png (deflated 3%)
#   adding: resunet/57.png (deflated 2%)
#   adding: resunet/54.png (deflated 3%)
#   adding: resunet/53.png (deflated 2%)
#   adding: resunet/1.png (deflated 3%)
#   adding: resunet/15.png (deflated 3%)
#   adding: resunet/17.png (deflated 2%)
#   adding: resunet/76.png (deflated 4%)
#   adding: resunet/7.png (deflated 3%)
#   adding: resunet/69.png (deflated 3%)
#   adding: resunet/67.png (deflated 3%)
#   adding: resunet/25.png (deflated 3%)
#   adding: resunet/82.png (deflated 3%)
#   adding: resunet/79.png (deflated 3%)
#   adding: resunet/4.png (deflated 2%)
#   adding: resunet/63.png (deflated 2%)
#   adding: resunet/81.png (deflated 4%)
#   adding: resunet/49.png (deflated 2%)
#   adding: resunet/97.png (deflated 3%)
#   adding: resunet/43.png (deflated 3%)
#   adding: resunet/29.png (deflated 3%)

# %%
# !zip -r ./unet.zip ./unet
# Out:
#   adding: unet/ (stored 0%)
#   adding: unet/23.png (deflated 4%)
#   adding: unet/13.png (deflated 3%)
#   adding: unet/68.png (deflated 2%)
#   adding: unet/31.png (deflated 3%)
#   adding: unet/5.png (deflated 3%)
#   adding: unet/62.png (deflated 2%)
#   adding: unet/59.png (deflated 3%)
#   adding: unet/19.png (deflated 2%)
#   adding: unet/60.png (deflated 4%)
#   adding: unet/93.png (deflated 3%)
#   adding: unet/48.png (deflated 3%)
#   adding: unet/37.png (deflated 3%)
#   adding: unet/35.png (deflated 2%)
#   adding: unet/73.png (deflated 3%)
#   adding: unet/11.png (deflated 3%)
#   adding: unet/77.png (deflated 2%)
#   adding: unet/45.png (deflated 2%)
#   adding: unet/55.png (deflated 2%)
#   adding: unet/83.png (deflated 4%)
#   adding: unet/33.png (deflated 3%)
#   adding: unet/34.png (deflated 3%)
#   adding: unet/86.png (deflated 3%)
#   adding: unet/80.png (deflated 2%)
#   adding: unet/50.png (deflated 4%)
#   adding: unet/30.png (deflated 4%)
#   adding: unet/94.png (deflated 4%)
#   adding: unet/95.png (deflated 2%)
#   adding: unet/21.png (deflated 3%)
#   adding: unet/89.png (deflated 4%)
#   adding: unet/28.png (deflated 3%)
#   adding: unet/41.png (deflated 4%)
#   adding: unet/51.png (deflated 4%)
#   adding: unet/84.png (deflated 4%)
#   adding: unet/71.png (deflated 3%)
#   adding: unet/10.png (deflated 3%)
#   adding: unet/75.png (deflated 4%)
#   adding: unet/85.png (deflated 3%)
#   adding: unet/6.png (deflated 3%)
#   adding: unet/39.png (deflated 3%)
#   adding: unet/27.png (deflated 3%)
#   adding: unet/46.png (deflated 5%)
#   adding: unet/12.png (deflated 3%)
#   adding: unet/38.png (deflated 3%)
#   adding: unet/90.png (deflated 3%)
#   adding: unet/2.png (deflated 5%)
#   adding: unet/74.png (deflated 2%)
#   adding: unet/56.png (deflated 3%)
#   adding: unet/64.png (deflated 3%)
#   adding: unet/47.png (deflated 3%)
#   adding: unet/36.png (deflated 3%)
#   adding: unet/26.png (deflated 3%)
#   adding: unet/99.png (deflated 3%)
#   adding: unet/20.png (deflated 4%)
#   adding: unet/42.png (deflated 2%)
#   adding: unet/91.png (deflated 4%)
#   adding: unet/66.png (deflated 3%)
#   adding: unet/24.png (deflated 3%)
#   adding: unet/9.png (deflated 3%)
#   adding: unet/32.png (deflated 2%)
#   adding: unet/0.png (deflated 3%)
#   adding: unet/65.png (deflated 3%)
#   adding: unet/44.png (deflated 3%)
#   adding: unet/72.png (deflated 2%)
#   adding: unet/98.png (deflated 3%)
#   adding: unet/88.png (deflated 3%)
#   adding: unet/96.png (deflated 4%)
#   adding: unet/18.png (deflated 4%)
#   adding: unet/87.png (deflated 3%)
#   adding: unet/22.png (deflated 2%)
#   adding: unet/78.png (deflated 2%)
#   adding: unet/92.png (deflated 4%)
#   adding: unet/58.png (deflated 3%)
#   adding: unet/52.png (deflated 4%)
#   adding: unet/16.png (deflated 3%)
#   adding: unet/61.png (deflated 3%)
#   adding: unet/40.png (deflated 2%)
#   adding: unet/8.png (deflated 3%)
#   adding: unet/70.png (deflated 2%)
#   adding: unet/3.png (deflated 2%)
#   adding: unet/14.png (deflated 3%)
#   adding: unet/57.png (deflated 2%)
#   adding: unet/54.png (deflated 3%)
#   adding: unet/53.png (deflated 2%)
#   adding: unet/1.png (deflated 3%)
#   adding: unet/15.png (deflated 3%)
#   adding: unet/17.png (deflated 2%)
#   adding: unet/76.png (deflated 4%)
#   adding: unet/7.png (deflated 3%)
#   adding: unet/69.png (deflated 3%)
#   adding: unet/67.png (deflated 3%)
#   adding: unet/25.png (deflated 3%)
#   adding: unet/82.png (deflated 3%)
#   adding: unet/79.png (deflated 3%)
#   adding: unet/4.png (deflated 2%)
#   adding: unet/63.png (deflated 3%)
#   adding: unet/81.png (deflated 4%)
#   adding: unet/49.png (deflated 3%)
#   adding: unet/97.png (deflated 3%)
#   adding: unet/43.png (deflated 3%)
#   adding: unet/29.png (deflated 3%)
